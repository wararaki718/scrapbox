# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
x = np.random.rand(1000000)
mu = np.mean(x) # lambda

# %%
y = -mu * np.log(1-x)

# %%
plt.hist(x)
plt.show()

# %%
plt.hist(y)
plt.show()
