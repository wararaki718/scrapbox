# %%
import os
import io
import time
import math

import torch
import torch.nn as nn
from torch.autograd import Variable
import esanpy
import pandas as pd
import tqdm

# %%
args = {
    'data': 'data',
    'model': 'LSTM',
    'emsize': 200,
    'nhid': 200,
    'nlayers': 2,
    'lr': 20,
    'clip': 0.25,
    'epochs': 100,
    'batch_size': 20,
    'bptt': 35,
    'dropout': 0.2,
    'tied': True,
    'seed': 42,
    'cuda': True,
    'log_interval': 1000,
    'save': 'model.pth',
    'temperature': 1.0,
    'outf': 'out.txt',
    'words': 1000
}

# %%
esanpy.start_server()

# %%
filepath = '/home/wararaki/workspace/git_repos/soseki/natsume.ndjson'

# %%
text_df = pd.read_json(filepath, orient='records', lines=True)

# %%
class Dictionary(object):
    def __init__(self):
        self.word2idx = {}
        self.idx2word = []

    def add_word(self, word):
        if word not in self.word2idx:
            self.idx2word.append(word)
            self.word2idx[word] = len(self.idx2word) - 1
        return self.word2idx[word]

    def __len__(self):
        return len(self.idx2word)

# %%
class Corpus(object):
    def __init__(self, path):
        self.dictionary = Dictionary()
        self.train = self.tokenize(path)
        self.valid = self.tokenize(path)
        self.test = self.tokenize(path)

    def tokenize(self, path):
        """Tokenizes a text file."""
        # Add words to the dictionary
        df = pd.read_json(path, orient='records', lines=True)
        tokens = 0
        for _, row in tqdm.tqdm(df.iterrows()):
            text = io.StringIO(row.get('text'))
            for line in text:
                words = esanpy.analyzer(line, analyzer='kuromoji_neologd')
                if len(words) == 0:
                    pass
                words += ['<eos>']
                tokens += len(words)
                for word in words:
                    self.dictionary.add_word(word)

        # Tokenize file content
        ids = torch.LongTensor(tokens)
        token = 0
        for _, row in tqdm.tqdm(df.iterrows()):
            text = io.StringIO(row.get('text'))
            for line in text:
                words = esanpy.analyzer(line, analyzer='kuromoji_neologd') + ['<eos>']
                for word in words:
                    ids[token] = self.dictionary.word2idx[word]
                    token += 1

        return ids

# %%
class RNNModel(nn.Module):
    """Container module with an encoder, a recurrent module, and a decoder."""

    def __init__(self, rnn_type, ntoken, ninp, nhid, nlayers, dropout=0.5, tie_weights=False):
        super(RNNModel, self).__init__()
        self.drop = nn.Dropout(dropout)
        self.encoder = nn.Embedding(ntoken, ninp)
        if rnn_type in ['LSTM', 'GRU']:
            self.rnn = getattr(nn, rnn_type)(ninp, nhid, nlayers, dropout=dropout)
        else:
            try:
                nonlinearity = {'RNN_TANH': 'tanh', 'RNN_RELU': 'relu'}[rnn_type]
            except KeyError:
                raise ValueError( """An invalid option for `--model` was supplied,
                                 options are ['LSTM', 'GRU', 'RNN_TANH' or 'RNN_RELU']""")
            self.rnn = nn.RNN(ninp, nhid, nlayers, nonlinearity=nonlinearity, dropout=dropout)
        self.decoder = nn.Linear(nhid, ntoken)

        # Optionally tie weights as in:
        # "Using the Output Embedding to Improve Language Models" (Press & Wolf 2016)
        # https://arxiv.org/abs/1608.05859
        # and
        # "Tying Word Vectors and Word Classifiers: A Loss Framework for Language Modeling" (Inan et al. 2016)
        # https://arxiv.org/abs/1611.01462
        if tie_weights:
            if nhid != ninp:
                raise ValueError('When using the tied flag, nhid must be equal to emsize')
            self.decoder.weight = self.encoder.weight

        self.init_weights()

        self.rnn_type = rnn_type
        self.nhid = nhid
        self.nlayers = nlayers

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.fill_(0)
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, input, hidden):
        emb = self.drop(self.encoder(input))
        output, hidden = self.rnn(emb, hidden)
        output = self.drop(output)
        decoded = self.decoder(output.view(output.size(0)*output.size(1), output.size(2)))
        return decoded.view(output.size(0), output.size(1), decoded.size(1)), hidden

    def init_hidden(self, bsz):
        weight = next(self.parameters()).data
        if self.rnn_type == 'LSTM':
            return (Variable(weight.new(self.nlayers, bsz, self.nhid).zero_()),
                    Variable(weight.new(self.nlayers, bsz, self.nhid).zero_()))
        else:
            return Variable(weight.new(self.nlayers, bsz, self.nhid).zero_())

# %%
torch.manual_seed(args['seed'])
if torch.cuda.is_available():
    if not args['cuda']:
        print("WARNING: You have a CUDA device, so you should probably run with --cuda")
    else:
        torch.cuda.manual_seed(args['seed'])

# %%
corpus = Corpus(filepath)
# Out:
# 118it [00:22,  5.28it/s]
# 118it [00:21,  5.39it/s]
# 118it [00:20,  5.87it/s]
# 118it [00:21,  5.36it/s]
# 118it [00:20,  5.70it/s]
# 118it [00:22,  5.21it/s]

# %%
def batchify(data, bsz):
    # Work out how cleanly we can divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    if args['cuda']:
        data = data.cuda()
    return data

# %%
eval_batch_size = 10
train_data = batchify(corpus.train, args['batch_size'])
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)

# %%
###############################################################################
# Build the model
###############################################################################

ntokens = len(corpus.dictionary)
model = RNNModel(args['model'], ntokens, args['emsize'], args['nhid'], args['nlayers'], args['dropout'], args['tied'])
if args['cuda']:
    model.cuda()

criterion = nn.CrossEntropyLoss()

# %%
###############################################################################
# Training code
###############################################################################

def repackage_hidden(h):
    """Wraps hidden states in new Variables, to detach them from their history."""
    #if type(h) == Variable:
    
    if isinstance(h, Variable):
        return Variable(h.data)
    else:
        return tuple(repackage_hidden(v) for v in h)

# %%
def get_batch(source, i, evaluation=False):
    seq_len = min(args['bptt'], len(source) - 1 - i)
    data = Variable(source[i:i+seq_len], volatile=evaluation)
    target = Variable(source[i+1:i+1+seq_len].view(-1))
    return data, target

# %%
def evaluate(data_source):
    # Turn on evaluation mode which disables dropout.
    model.eval()
    total_loss = 0
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(eval_batch_size)
    for i in range(0, data_source.size(0) - 1, args['bptt']):
        data, targets = get_batch(data_source, i, evaluation=True)
        output, hidden = model(data, hidden)
        output_flat = output.view(-1, ntokens)
        total_loss += len(data) * criterion(output_flat, targets).data
        hidden = repackage_hidden(hidden)
    return total_loss / len(data_source)

# %%
def train():
    # Turn on training mode which enables dropout.
    model.train()
    total_loss = 0
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(args['batch_size'])
    for batch, i in enumerate(range(0, train_data.size(0) - 1, args['bptt'])):
        data, targets = get_batch(train_data, i)
        # Starting each batch, we detach the hidden state from how it was previously produced.
        # If we didn't, the model would try backpropagating all the way to start of the dataset.
        hidden = repackage_hidden(hidden)
        model.zero_grad()
        output, hidden = model(data, hidden)
        loss = criterion(output.view(-1, ntokens), targets)
        loss.backward()

        # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
        torch.nn.utils.clip_grad_norm(model.parameters(), args['clip'])
        for p in model.parameters():
            p.data.add_(-lr, p.grad.data)

        total_loss += loss.data

        if batch % args['log_interval'] == 0 and batch > 0:
            #print(total_loss)
            #print(args['log_interval'])
            cur_loss = total_loss / args['log_interval']
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.2f} | ms/batch {:5.2f} | '
                    'loss {:5.2f} | ppl {:8.2f}'.format(
                epoch, batch, len(train_data) // args['bptt'], lr,
                elapsed * 1000 / args['log_interval'], cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()

# Loop over epochs.
lr = args['lr']
best_val_loss = None

# %%
# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(1, args['epochs']+1):
        epoch_start_time = time.time()
        train()
        val_loss = evaluate(val_data)
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
                'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                           val_loss, math.exp(val_loss)))
        print('-' * 89)
        # Save the model if the validation loss is the best we've seen so far.
        if not best_val_loss or val_loss < best_val_loss:
            with open(args['save'], 'wb') as f:
                torch.save(model, f)
            best_val_loss = val_loss
        else:
            # Anneal the learning rate if no improvement has been seen in the validation dataset.
            lr /= 4.0
except KeyboardInterrupt:
    print('-' * 89)
    print('Exiting from training early')
# Out:
# /home/wararaki/.pyenv/versions/3.7.0/lib/python3.7/site-packages/ipykernel_launcher.py:19: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# /home/wararaki/.pyenv/versions/3.7.0/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time:  9.85s | valid loss  7.74 | valid ppl  2302.20
# -----------------------------------------------------------------------------------------
# /home/wararaki/.pyenv/versions/3.7.0/lib/python3.7/site-packages/torch/serialization.py:250: UserWarning: Couldn't retrieve source code for container of type RNNModel. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time:  8.89s | valid loss  7.06 | valid ppl  1163.56
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time:  8.94s | valid loss  6.74 | valid ppl   849.01
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time:  9.25s | valid loss  6.48 | valid ppl   651.24
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time:  9.05s | valid loss  6.27 | valid ppl   529.95
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time:  8.94s | valid loss  6.15 | valid ppl   470.20
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time:  9.00s | valid loss  5.97 | valid ppl   391.04
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time:  9.05s | valid loss  5.85 | valid ppl   346.40
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time:  9.06s | valid loss  5.71 | valid ppl   302.72
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time:  9.05s | valid loss  5.62 | valid ppl   276.86
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time:  9.06s | valid loss  5.54 | valid ppl   255.09
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time:  9.07s | valid loss  5.50 | valid ppl   243.72
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time:  9.09s | valid loss  5.42 | valid ppl   226.84
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time:  9.08s | valid loss  5.37 | valid ppl   213.84
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time:  9.08s | valid loss  5.36 | valid ppl   213.55
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time:  9.08s | valid loss  5.22 | valid ppl   185.69
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time:  9.07s | valid loss  5.20 | valid ppl   180.57
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time:  9.10s | valid loss  5.14 | valid ppl   169.90
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time:  9.14s | valid loss  5.08 | valid ppl   160.09
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time:  9.13s | valid loss  5.06 | valid ppl   157.73
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time:  9.13s | valid loss  5.02 | valid ppl   150.74
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time:  9.13s | valid loss  5.02 | valid ppl   150.93
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time:  9.12s | valid loss  4.76 | valid ppl   117.28
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time:  9.13s | valid loss  4.72 | valid ppl   112.43
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time:  9.13s | valid loss  4.67 | valid ppl   106.81
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time:  9.13s | valid loss  4.65 | valid ppl   104.21
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time:  9.13s | valid loss  4.60 | valid ppl    99.25
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time:  9.13s | valid loss  4.56 | valid ppl    95.93
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time:  9.13s | valid loss  4.55 | valid ppl    95.10
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time:  9.13s | valid loss  4.53 | valid ppl    92.32
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time:  9.13s | valid loss  4.49 | valid ppl    89.35
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time:  9.13s | valid loss  4.48 | valid ppl    88.17
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time:  9.13s | valid loss  4.46 | valid ppl    86.66
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time:  9.14s | valid loss  4.46 | valid ppl    86.38
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time:  9.14s | valid loss  4.43 | valid ppl    83.98
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time:  9.13s | valid loss  4.41 | valid ppl    82.29
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time:  9.12s | valid loss  4.40 | valid ppl    81.70
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time:  9.13s | valid loss  4.39 | valid ppl    81.02
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time:  9.13s | valid loss  4.35 | valid ppl    77.71
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time:  9.14s | valid loss  4.37 | valid ppl    78.93
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  41 | time:  9.20s | valid loss  4.28 | valid ppl    72.26
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  42 | time:  9.28s | valid loss  4.27 | valid ppl    71.28
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  43 | time:  9.14s | valid loss  4.25 | valid ppl    70.09
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  44 | time:  9.14s | valid loss  4.24 | valid ppl    69.48
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  45 | time:  9.13s | valid loss  4.23 | valid ppl    68.76
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  46 | time:  9.13s | valid loss  4.23 | valid ppl    68.56
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  47 | time:  9.13s | valid loss  4.21 | valid ppl    67.40
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  48 | time:  9.14s | valid loss  4.21 | valid ppl    67.19
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  49 | time:  9.13s | valid loss  4.20 | valid ppl    66.67
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  50 | time:  9.14s | valid loss  4.19 | valid ppl    66.06
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  51 | time:  9.13s | valid loss  4.19 | valid ppl    65.84
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  52 | time:  9.13s | valid loss  4.19 | valid ppl    65.79
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  53 | time:  9.13s | valid loss  4.18 | valid ppl    65.62
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  54 | time:  9.14s | valid loss  4.17 | valid ppl    64.88
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  55 | time:  9.27s | valid loss  4.17 | valid ppl    64.81
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  56 | time:  9.13s | valid loss  4.16 | valid ppl    64.35
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  57 | time:  9.22s | valid loss  4.16 | valid ppl    64.19
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  58 | time:  9.14s | valid loss  4.15 | valid ppl    63.43
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  59 | time:  9.18s | valid loss  4.15 | valid ppl    63.61
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  60 | time:  9.84s | valid loss  4.13 | valid ppl    62.33
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  61 | time:  9.22s | valid loss  4.13 | valid ppl    62.11
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  62 | time:  9.13s | valid loss  4.13 | valid ppl    62.07
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  63 | time:  9.46s | valid loss  4.13 | valid ppl    62.00
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  64 | time:  9.14s | valid loss  4.12 | valid ppl    61.62
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  65 | time:  9.14s | valid loss  4.12 | valid ppl    61.55
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  66 | time:  9.14s | valid loss  4.12 | valid ppl    61.41
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  67 | time:  9.14s | valid loss  4.12 | valid ppl    61.52
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  68 | time:  9.14s | valid loss  4.10 | valid ppl    60.05
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  69 | time:  9.14s | valid loss  4.09 | valid ppl    59.89
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  70 | time:  9.13s | valid loss  4.09 | valid ppl    59.92
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  71 | time:  9.13s | valid loss  4.05 | valid ppl    57.32
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  72 | time:  9.13s | valid loss  4.05 | valid ppl    57.26
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  73 | time:  9.13s | valid loss  4.05 | valid ppl    57.28
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  74 | time:  9.13s | valid loss  4.05 | valid ppl    57.17
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  75 | time:  9.14s | valid loss  4.04 | valid ppl    57.11
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  76 | time:  9.18s | valid loss  4.04 | valid ppl    57.06
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  77 | time:  9.15s | valid loss  4.04 | valid ppl    57.05
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  78 | time:  9.14s | valid loss  4.04 | valid ppl    57.03
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  79 | time:  9.13s | valid loss  4.04 | valid ppl    56.99
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  80 | time:  9.13s | valid loss  4.04 | valid ppl    56.99
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  81 | time:  9.14s | valid loss  4.04 | valid ppl    56.96
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  82 | time:  9.15s | valid loss  4.04 | valid ppl    56.94
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  83 | time:  9.42s | valid loss  4.04 | valid ppl    56.92
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  84 | time:  9.13s | valid loss  4.04 | valid ppl    56.91
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  85 | time:  9.13s | valid loss  4.04 | valid ppl    56.89
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  86 | time:  9.13s | valid loss  4.04 | valid ppl    56.88
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  87 | time:  9.14s | valid loss  4.04 | valid ppl    56.87
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  88 | time:  9.14s | valid loss  4.04 | valid ppl    56.87
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  89 | time:  9.14s | valid loss  4.04 | valid ppl    56.86
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  90 | time:  9.19s | valid loss  4.04 | valid ppl    56.86
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  91 | time:  9.14s | valid loss  4.04 | valid ppl    56.85
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  92 | time:  9.14s | valid loss  4.04 | valid ppl    56.85
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  93 | time:  9.13s | valid loss  4.04 | valid ppl    56.84
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  94 | time:  9.13s | valid loss  4.04 | valid ppl    56.84
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  95 | time:  9.14s | valid loss  4.04 | valid ppl    56.83
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  96 | time:  9.14s | valid loss  4.04 | valid ppl    56.83
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  97 | time:  9.14s | valid loss  4.04 | valid ppl    56.83
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  98 | time:  9.21s | valid loss  4.04 | valid ppl    56.82
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch  99 | time:  9.13s | valid loss  4.04 | valid ppl    56.82
# -----------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------
# | end of epoch 100 | time:  9.14s | valid loss  4.04 | valid ppl    56.81
# -----------------------------------------------------------------------------------------

# %%
# Load the best saved model.
with open(args['save'], 'rb') as f:
    model = torch.load(f)

# %%
# Run on test data.
test_loss = evaluate(test_data)
print('=' * 89)
print('| End of training | test loss {:5.2f} | test ppl {:8.2f}'.format(
    test_loss, math.exp(test_loss)))
print('=' * 89)
# Out:
# /home/wararaki/.pyenv/versions/3.7.0/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# =========================================================================================
# | End of training | test loss  4.04 | test ppl    56.81
# =========================================================================================

# %% [markdown]
# ## Generate Text

# %%
with open(args['save'], 'rb') as f:
    model = torch.load(f)
model.eval()

if args['cuda']:
    model.cuda()
else:
    model.cpu()

# %%
corpus = Corpus(filepath)
ntokens = len(corpus.dictionary)
hidden = model.init_hidden(1)
input = Variable(torch.rand(1, 1).mul(ntokens).long(), volatile=True)
if args['cuda']:
    input.data = input.data.cuda()
# Out:
# 118it [00:21,  5.56it/s]
# 118it [00:22,  5.18it/s]
# 118it [00:21,  5.57it/s]
# 118it [00:21,  5.41it/s]
# 118it [00:20,  5.62it/s]
# 118it [00:22,  5.36it/s]
# /home/wararaki/.pyenv/versions/3.7.0/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   after removing the cwd from sys.path.

# %%
text = ''
with open(args['outf'], 'wb') as outf:
    line = ''
    for i in range(args['words']):
        output, hidden = model(input, hidden)
        word_weights = output.squeeze().data.div(args['temperature']).exp().cpu()
        word_idx = torch.multinomial(word_weights, 1)[0]
        input.data.fill_(word_idx)
        word = corpus.dictionary.idx2word[word_idx]
        #if word == '<eos>':
        #    word = '、'

        #print(word)
        if word == '<eos>':
            word = '\n'
            line += word
            if line == '\n':
                pass
            else:
                text += line
                print(line)
            line = ''
        else:
            word += ''
            line += word

#        if i % args['log_interval'] == 0:
#            print('| Generated {}/{} words'.format(i, args['words']))
# Out:
# あがる商売えらい早い買う来る
#
# これから三五日前同じ事聞く上等事笑われる
#
# 老人道具祭日得学校通う来る後少し
#
# 下向く直す云うあまり軽い御母さんつけ加える
#
# 何事違う驚くそこ下唐津人指し指全快参上思う
#
# あまりく一人儲くもん
#
# そんな御困る方妻帯まま
#
# そうわたし何御約束今日出来る事頼む
#
# ええいや
#
# 浜田たん
#
# 下女若い女婦人会会もらう気がつく様子
#
# 時時継
#
# 那古井棄真紅とまる煽る白雲平生取り落す
#
# 見るこうとうとう碧飲む時少しく無愛想相手思う
#
# あの女頼む
#
# 私和尚さんかい
#
# まだ御誂えるいくら奥さん生れ相当分る甲野さん笑う
#
# 若い女気出来
#
# せん細君簡単思う事覚える
#
# そんな画考しょう
#
# 御尤も
#
# 有る事云う害奴有馬線
#
# どうして困るこの間きまるかね
#
# そんなに元来おれ今何そんな事云う何加減知る
#
# 正直どうしても困る見える早速明仕方がない
#
# さも気楽仕方がない待った
#
# まるでこまやか心返す
#
# ちる
#
# こう言うおかしい今思う
#
# えなかりる思う
#
# そんな事そう
#
# 同じ無い
#
# なに似る面白い
#
# 随分面白い良い呑気剣呑
#
# 全体動何とも
#
# あの女怒るそうさな第二単語広告だいぶthe近いハハハハ
#
# 近々探偵
#
# 山越君どう
#
# 何
#
# 知る君そんなあう
#
# 何高木遊ぶ行く聞すいや
#
# 単なる書く様子分る
#
# あなた本当に逢う
#
# 半熟そう理
#
# 誰か
#
# 発句
#
# 達磨知る
#
# 随分御役に立つ申す難題
#
# 遠慮行うとうてい仕合
#
# いっそ方あのわずかたしか気多事
#
# そう事いずれ来る
#
# 御前真面真面目目見様云う訳なっちまう
#
# どっちもうどこ
#
# 来る毫思う何買う
#
# 今何関係出来るいける云う
#
# ええ寒月君知る私困る
#
# 近頃困る何だか分るそう余計事図案千里そうとにかくええみんな早い甲野君察す好い
#
# いいえ聞くええ駄目
#
# 分る少々変
#
# なに体鼻云う妙話繰り返す余腹立つ一人叶うおるなんやっぱり相手非常妙こう
#
# いやきめるおわるくるだいぶ真面目すべて自信もつにくい証拠一人外交外交官官試験落第たしか
#
# 奇麗今頃目何度色々音置く来る
#
# 一体そんな考いけるあなたこちら御口見る
#
# 二三日長い間立待ち乗り越える
#
# まず世君と僕送り込む
#
# そう
#
# そう天下正直世の中他人知るこう云ういろいろ大切思うああ云う考云う句聞くおかしい考えるわるい君話思い出す
#
# そうそりゃ分るこの間取り上げる帰る行く
#
# 何訳持つ貰えるどうせあの人同じ事今日こっち何
#
# 構ういや女癖切る頂ける
#
# やっぱり返す
#
# どこ行く
#
# なぜこれから強情多少きまりざんする一手少し骨なか
#
# どうか
#
# へえさっき黙る
#
# そりゃ行くいける
#
# 何云う
#
# 私実際車掌どんなえらい立派内部見る
#
# 何事
#
# ええ人蒼生きるてる云うおう何考知るてる
#
# 欠ける困るああ心配甲斐生きるやる知れる癖
#
# 方敬太郎すぐ多々良君方当る
#
# 僕哲学哲学者者方
#
# 何
#
# 勇気なさる話す歴史知る余裕
#
# そんな熱心まだ幾一人前発達
#
# 山の芋結婚いい高等高等学校学校時代書く踴いづ定める
#
# 君知る三四郎首縊りカラ取り出す
#
# 三十円教室中九時間もうけちいぬ
#
# そうこんな奔走電車乗る窓外這入るくる声冴思う
#
# ハハハ御者角屋乗るなるほど甘干し柿押すしばし高柳君弱る知れる
#
# そりゃ大丈夫遠慮ない坊くちる
#
# 先生御者持つ参るあと
#
# 僕ともかく亭主先生代る
#
# なるほど
#
# あ
#
# 二人遠慮果物吹く勿体気あう
#
# 四五日間もう二人中聞く奥出る
#
# 君高等高等学校学校出席先生いつもすい
#
# あすこ思う
#
# 知る細君顔揃える新年中職員今自転車乗る事遍い
#
# 六
#
# 曾相思衣くる見る行く金田笑うにくい
#
# こんな景色来る時間くさくさ下つづら習う見る
#
# 馬鹿馬鹿しい津田君夕飯はまる
#
# あれ短評長々すこぶる議論
#
# 屁一番酒意地張り必ずしもそいつ君猟自殺付ける内科
#
# 何あすこ何だか酷評見る山茶花後足電車楽隊谷底懸る述べる
#
# 冗談とにかく君鼻先入る一番電力気楽惜しい事
#
# そう苦しい音来る
#
# 本当に三時眼忘れる時黒い煙ほてる
#
# 君一人云う出し手来る
#
# あなた一人御御両人出来る
#
# なに急違う迷亭君
#
# はあそう
#
# はあ御納める
#
# 後れる新橋出る
#
# 御遠慮ないどうなする主人主人返事
#
# あなた和尚御荷物どうしてすっかり来るがる
#
# 久一さん頸時だいぶ画出る
#
# 人venus
#
# そう
#
# 知る東風君全体見る屈原柿行く
#
# 安さんおや
#
# いえる三人すう独習聞く
#
# おれちょっと奇麗なさる何寒月君近所猫見る夫婦。前厚い帯しめる神さんいっしょ歩く先生向う名知る
#
# 食う見る見るたまえ
#
# 転地いいあすこ来る気品物やる個性美事御化粧思う
#
# そうよい事たしかに御気の毒
#
# これから進む今度無いこう打ち壊すしまう第一人一段落かかる
#
# 主人玄関上る書斎
#
# まだ一時間婆さん秋断ち切る杭
#
# 加減いいぬっくと出す奥脱見るなかいつものように傘けた
#
# どこ用
#
# 先生寒いおいあとやる訳
#
# こう云う雨御水注
#
# 女まだ云うまあ御嬢さんああ男御用くれる
